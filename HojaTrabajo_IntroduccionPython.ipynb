# %% [markdown]
# # Hoja de Trabajo — Introducción a Python
#
# **Nombre:** Rubén de Jesús Samayoa Girón
# **Carnet:** 202607157
# **Fecha:** 13/04/2026
#
# ---
#
# Instrucciones generales:
# - Completa cada celda de código donde se indica `# TU CÓDIGO AQUÍ`.
# - No borres las instrucciones ni los comentarios de guía.
# - Ejecuta cada celda para verificar que tu solución es correcta.
# - Puedes consultar el script `introduccion_python.py` como referencia.

# %% [markdown]
# ---
# ## 1. Hola Mundo y `print()`
#
# La función `print()` muestra texto en pantalla. Puede recibir varios argumentos separados por comas y tiene el parámetro `end` para controlar cómo termina la línea.

# %%
# Ejercicio 1a
# Imprime tu nombre y carnet en una sola línea usando print() con dos argumentos.
# Ejemplo de salida esperada:  Nombre: Ana  Carnet: 202300001

print('nombre: Rubén de Jesús Samayoa Girón, carnet: 202607157')

# %%
# Ejercicio 1b
# Usa end="" para imprimir las palabras "Hola", "desde" y "Python"
# en una sola línea, cada una en su propia llamada a print().
# Salida esperada:  Hola desde Python

print( 'hola', end=' ')
print( 'desde', end=' ')
print( 'python')

# %% [markdown]
# ---
# ## 2. Variables y tipos de datos
#
# Python es de **tipado dinámico**: no necesitas declarar el tipo, se asigna automáticamente.
# Tipos básicos: `int`, `float`, `str`, `bool`, `NoneType`.

# %%
# Ejercicio 2a
# Crea variables con los siguientes datos sobre ti:
#   - nombre     (str)   con tu nombre completo
#   - edad       (int)   con tu edad
#   - promedio   (float) con un promedio de notas inventado
#   - activo     (bool)  True si eres estudiante activo
# Luego imprime cada variable junto con su tipo usando type().__name__

 nombre = 'Rubén de Jesús Samayoa Girón'
edad = 18
promedio = 70.56
activo = True
print(nombre, type(nombre).__name__)
print(edad, type(edad).__name__)
print(promedio, type(promedio).__name__)
print(activo, type(activo).__name__)

# %%
# Ejercicio 2b
# Usa asignación múltiple para crear tres variables x, y, z
# con los valores 10, 20 y 30 en una sola línea.
# Luego imprime: "x=10, y=20, z=30" usando un f-string.

x, y, z = 10, 20, 30
print(f'x={x}, y={y}, z={z}')

# %% [markdown]
# ---
# ## 3. Operaciones aritméticas
#
# Python tiene los operadores: `+`, `-`, `*`, `/` (división real), `//` (división entera), `%` (módulo), `**` (potencia).
# El módulo `math` ofrece funciones como `sqrt`, `ceil`, `floor`.

# %%
# Ejercicio 3a
# Dados a=23 y b=7, calcula e imprime:
#   - La división entera de a entre b
#   - El residuo (módulo) de a entre b
#   - a elevado a la potencia b (solo los primeros dígitos, usa f-string)

a, b = 23, 7

b=7
a=23
D = a // b
R = a % b
P = a ** b
print(f'La división entera de {a} entre {b} es: {D}')
print(f'El residuo (módulo) de {a} entre {b} es: {R}')
P_str = str(P)print(f'{a} elevado a la potencia {b} (primeros dígitos): {P_str[:4]}')

# %%
# Ejercicio 3b
# Usa el módulo math para calcular:
#   1. La raíz cuadrada de 144
#   2. El techo (ceil) de 7.3
#   3. El piso (floor) de 7.9
#   4. El valor de pi redondeado a 4 decimales (usa :.4f en el f-string)

import math

import math
raiz = math.sqrt(144)
techo = math.ceil(7.3)
piso = math.floor(7.9)
valor_pi = math.pi

print(f'La raíz cuadrada de 144 es: {raiz}')
print(f'El techo de 7.3 es: {techo}')
print(f'El piso de 7.9 es: {piso}')
print(f'El valor de pi redondeado es: {valor_pi:.4f}')

# %% [markdown]
# ---
# ## 4. Strings y métodos útiles
#
# Los strings tienen métodos como `.strip()`, `.upper()`, `.lower()`, `.replace()`, `.split()`, `.join()`.
# Los **f-strings** permiten insertar variables directamente en el texto: `f"Hola {nombre}"`.

# %%
# Ejercicio 4a
# Dada la cadena: "  fisica y matematica  "
# Aplica los métodos para:
#   1. Quitar espacios extremos
#   2. Convertir a mayúsculas
#   3. Reemplazar "Y" por "&"
# Imprime el resultado de cada paso.

cadena = "  fisica y matematica  "

cadena = ' fisica y matematica ' 
cadena_limpia = cadena.strip()
print(f'1. Sin espacios: "{cadena_limpia}"')

cadena_mayus = cadena_limpia.upper()
print(f'2. En mayúsculas: {cadena_mayus}')

cadena_final = cadena_mayus.replace('Y', '&')
print(f'3. Resultado final: {cadena_final}')

# %%
# Ejercicio 4b
# Dada la cadena: "rojo-verde-azul-amarillo"
# 1. Sepárala en una lista de colores usando split()
# 2. Une la lista con " | " usando join()
# 3. Verifica con 'in' si "verde" está en la lista (imprime True/False)

colores_str = "rojo-verde-azul-amarillo"

colores_str = 'rojo-verde-azul-amarillo'
lista_colores = colores_str.split('-')
print(f'1. Lista de colores: {lista_colores}')

colores_unidos = ' | '.join(lista_colores)
print(f'2. Colores unidos: {colores_unidos}')

esta_verde = 'verde' in lista_colores
print(f'3. ¿Está el color verde?: {esta_verde}')

# %% [markdown]
# ---
# ## 5. Listas
#
# Las listas son **mutables** y se crean con `[]`. Métodos principales: `.append()`, `.insert()`, `.remove()`, `.pop()`.
# Funciones útiles: `len()`, `min()`, `max()`, `sum()`, `sorted()`.

# %%
# Ejercicio 5a
# Crea una lista con las materias: "Cálculo", "Física", "Programación", "Álgebra"
# Luego:
#   1. Agrega "Estadística" al final
#   2. Inserta "Química" en la posición 2
#   3. Elimina "Álgebra" de la lista
#   4. Imprime la lista final y su longitud

materias = ['Cálculo', 'Física', 'Programación', 'Álgebra']
materias.append('Estadística')
materias.insert(2, 'Química')
materias.remove('Álgebra')

print(f'Lista final de materias: {materias}')
print(f'Longitud de la lista: {len(materias)}')

# %%
# Ejercicio 5b
# Dada la lista de notas, imprime: mínimo, máximo, suma y promedio.
# El promedio debe mostrarse con 2 decimales usando f-string :.2f

notas = [78, 92, 65, 88, 74, 95, 61, 83]

notas = [78, 92, 65, 88, 74, 95, 61, 83]
nota_minima = min(notas)
nota_maxima = max(notas)
suma_notas = sum(notas)
promedio = suma_notas / len(notas)

print(f'Mínimo: {nota_minima}')
print(f'Máximo: {nota_maxima}')
print(f'Suma: {suma_notas}')
print(f'Promedio: {promedio:.2f}')

# %% [markdown]
# ---
# ## 6. Diccionarios
#
# Los diccionarios almacenan pares **clave → valor**. Se crean con `{}`.
# Para acceder de forma segura usa `.get(clave, valor_por_defecto)`.
# Para iterar sobre pares: `for clave, valor in d.items():`

# %%
# Ejercicio 6a
# Crea un diccionario que represente un curso con las claves:
#   "nombre", "codigo", "creditos", "activo"
# Luego:
#   1. Agrega la clave "estudiantes" con el valor 35
#   2. Imprime el valor de "creditos" usando .get()
#   3. Intenta obtener la clave "salon" con valor por defecto "Sin asignar"

curso = {
    'nombre': 'Programación 1',
    'codigo': '0123',
    'creditos': 5,
    'activo': True
}
curso['estudiantes'] = 35
print(f'Créditos del curso: {curso.get("creditos")}')
salon = curso.get('salon', 'Sin asignar')
print(f'Ubicación: {salon}')

# %%
# Ejercicio 6b
# Itera sobre el diccionario del ejercicio anterior e imprime
# cada clave y su valor en el formato:  clave     : valor
# (usa f-string con alineación, ej: f"{clave:12} : {valor}")

print('Detalles del curso:')
for clave, valor in curso.items():
    print(f'{clave:12} : {valor}')

# %% [markdown]
# ---
# ## 7. Condicionales
#
# Estructura: `if condición:` / `elif condición:` / `else:`
# Operador ternario (en una línea): `valor_si_true if condición else valor_si_false`

# %%
# Ejercicio 7a
# Escribe una función llamada clasificar_imc(imc) que reciba el
# Índice de Masa Corporal y retorne una cadena según esta escala:
#   < 18.5  → "Bajo peso"
#   18.5–24.9 → "Normal"
#   25–29.9 → "Sobrepeso"
#   >= 30   → "Obesidad"
#
# Pruébala con los valores: 16.0, 22.5, 27.3, 31.8

def clasificar_imc(imc):
    if imc < 18.5:
        return 'Bajo peso'
    elif imc < 25:
        return 'Normal'
    elif imc < 30:
        return 'Sobrepeso'
    else:
        return 'Obesidad'

# Pruebas
valores = [16.0, 22.5, 27.3, 31.8]
for v in valores:
    print(f'IMC {v}: {clasificar_imc(v)}')

# %%
# Ejercicio 7b
# Usa el operador ternario para determinar si un número es par o impar.
# Pruébalo con los números 4, 7 y 0.
# Salida esperada:  4 es par  /  7 es impar  /  0 es par

numeros = [4, 7, 0]

for n in numeros:
    # Determinamos el resultado en una sola línea
    resultado = 'par' if n % 2 == 0 else 'impar'
    print(f'{n} es {resultado}')

# %% [markdown]
# ---
# ## 8. Ciclos
#
# - `for elemento in iterable:` — recorre cada elemento
# - `for i in range(inicio, fin, paso):` — secuencia numérica
# - `for i, val in enumerate(lista):` — índice + valor
# - `while condición:` — repite mientras la condición sea verdadera
# - **List comprehension:** `[expresión for x in iterable if condición]`

# %%
# Ejercicio 8a
# Usa un for con enumerate() para imprimir la siguiente lista de planetas
# numerados desde 1.
# Salida esperada:
#   [1] Mercurio
#   [2] Venus
#   ...

planetas = ["Mercurio", "Venus", "Tierra", "Marte", "Júpiter", "Saturno", "Urano", "Neptuno"]

planetas = ['Mercurio', 'Venus', 'Tierra', 'Marte', 'Júpiter', 'Saturno', 'Urano', 'Neptuno']

for i, planeta in enumerate(planetas, start=1):
    print(f'[{i}] {planeta}')

# %%
# Ejercicio 8b
# Usa un ciclo while para imprimir la tabla de multiplicar del 7
# (del 7x1 hasta el 7x10).
# Formato:  7 x 1 = 7

i = 1
while i <= 10:
    resultado = 7 * i
    print(f'7 x {i} = {resultado}')
    i += 1

# %%
# Ejercicio 8c — List comprehension
# En una sola línea, crea las siguientes listas y luego imprímelas:
#   1. Los cubos de los números del 1 al 8  (x³)
#   2. Los números del 1 al 30 que sean divisibles por 3 pero NO por 9

cubos = [x**3 for x in range(1, 9)]
print(f'Cubos: {cubos}')

filtrados = [n for n in range(1, 31) if n % 3 == 0 and n % 9 != 0]
print(f'Divisibles por 3 y no por 9: {filtrados}')

# %% [markdown]
# ---
# ## 9. Funciones
#
# ```python
# def nombre_funcion(param1, param2=valor_defecto):
#     """Docstring: descripción breve."""
#     return resultado
# ```
# Una función puede retornar **múltiples valores** (como tupla) y llamarse a sí misma (**recursión**).

# %%
# Ejercicio 9a
# Escribe una función convertir_temperatura(grados, escala="C") que convierta:
#   - Si escala="C"  → convierte Celsius a Fahrenheit: F = C * 9/5 + 32
#   - Si escala="F"  → convierte Fahrenheit a Celsius: C = (F - 32) * 5/9
#
# Pruébala con: 100°C, 0°C, 32°F y 212°F

def convertir_temperatura(grados, escala='C'):
    if escala == 'C':
        resultado = grados * 9/5 + 32
        return f'{grados}°C son {resultado}°F'
    elif escala == 'F':
        resultado = (grados - 32) * 5/9
        return f'{grados}°F son {resultado}°C'

print(convertir_temperatura(100))
print(convertir_temperatura(0, 'C'))
print(convertir_temperatura(32, 'F'))
print(convertir_temperatura(212, 'F'))

# %%
# Ejercicio 9b
# Escribe una función resumen_lista(lista) que retorne
# tres valores: (minimo, maximo, promedio).
# Úsala con: [12, 45, 7, 89, 34, 56, 23]
# Imprime los tres resultados usando desempaquetado.

def resumen_lista(lista):
    minimo = min(lista)
    maximo = max(lista)
    promedio = sum(lista) / len(lista)
    return minimo, maximo, promedio

numeros = [12, 45, 7, 89, 34, 56, 23]
mi_min, mi_max, mi_prom = resumen_lista(numeros)

print(f'Mínimo: {mi_min}')
print(f'Máximo: {mi_max}')
print(f'Promedio: {mi_prom:.2f}')

# %%
# Ejercicio 9c — Recursión
# Escribe una función recursiva fibonacci(n) que retorne
# el n-ésimo número de la sucesión de Fibonacci.
# Casos base: fibonacci(0)=0, fibonacci(1)=1
# Caso recursivo: fibonacci(n) = fibonacci(n-1) + fibonacci(n-2)
#
# Imprime los primeros 10 números: fibonacci(0) ... fibonacci(9)

def fibonacci(n):
    if n == 0:
        return 0
    if n == 1:
        return 1
    return fibonacci(n - 1) + fibonacci(n - 2)

for i in range(10):
    print(f'fibonacci({i}) = {fibonacci(i)}')

# %% [markdown]
# ---
# ## 10. Manejo de errores
#
# ```python
# try:
#     # código que puede fallar
# except TipoDeError as e:
#     # qué hacer si ocurre el error
# finally:
#     # se ejecuta siempre
# ```
# Para lanzar un error explícitamente: `raise ValueError("mensaje")`

# %%
# Ejercicio 10a
# Escribe una función convertir_entero(valor) que intente convertir
# el parámetro a entero usando int().
#   - Si tiene éxito, retorna el entero.
#   - Si ocurre un ValueError, imprime un mensaje de error y retorna None.
#   - El bloque finally debe imprimir "[intento con: <valor>]" siempre.
#
# Pruébala con: "42", "3.14", "hola", 100

def convertir_entero(valor):
    try:
        resultado = int(valor)
        return resultado
    except ValueError as e:
        print(f'Error de valor: No se pudo convertir "{valor}"')
        return None
    finally:
        print(f'Intento con: {valor}')

print(f'Resultado: {convertir_entero("42")}\n')
print(f'Resultado: {convertir_entero("3.14")}\n') 
print(f'Resultado: {convertir_entero("hola")}\n')
print(f'Resultado: {convertir_entero(100)}\n')

# %%
# Ejercicio 10b
# Escribe una función validar_edad(edad) que:
#   - Lance un TypeError  si edad no es int
#   - Lance un ValueError si edad < 0 o edad > 150
#   - Retorne True si la edad es válida
#
# Pruébala dentro de un try/except con: 25, -5, 200, "veinte"

def validar_edad(edad):
    if not isinstance(edad, int):
        raise TypeError('La edad debe ser un número entero.')
    
    if edad < 0 or edad > 150:
        raise ValueError('La edad debe estar entre 0 y 150 años.')
    
    return True

valores_prueba = [25, -5, 200, 'veinte']

for v in valores_prueba:
    try:
        if validar_edad(v):
            print(f'Edad {v} es válida.')
    except (TypeError, ValueError) as e:
        print(f'Entrada {v} rechazada: {e}')

# %% [markdown]
# ---
# ## Ejercicio integrador
#
# Combina lo aprendido en un mini-programa completo.

# %%
# Ejercicio integrador
#
# Crea una función analizar_curso(estudiantes) que reciba una lista de
# diccionarios. Cada diccionario representa un estudiante con las claves:
#   "nombre" (str), "notas" (lista de ints)
#
# La función debe:
#   1. Calcular el promedio de cada estudiante (retorna None si notas está vacía)
#   2. Clasificar al estudiante: promedio >= 61 → "Aprobado", si no → "Reprobado"
#   3. Imprimir una tabla con: nombre, promedio (2 decimales) y estado
#   4. Al final, imprimir cuántos aprobaron y cuántos reprobaron
#
# Usa el siguiente listado de prueba:

curso = [
    {"nombre": "Ana López",    "notas": [85, 90, 78, 92]},
    {"nombre": "Carlos Ruiz",  "notas": [55, 48, 60, 52]},
    {"nombre": "María Paz",    "notas": [70, 75, 68, 80]},
    {"nombre": "Luis Gómez",   "notas": [95, 98, 100, 92]},
    {"nombre": "Sara Díaz",    "notas": [40, 55, 50, 45]},
    {"nombre": "Pedro Alva",   "notas": []},
]

def analizar_curso(estudiantes):
    aprobados = 0
    reprobados = 0
    
    print(f'{ "Nombre":<15} | { "Promedio":<10} | { "Estado"}')
    print('-' * 40)
    
    for estudiante in estudiantes:
        nombre = estudiante['nombre']
        notas = estudiante['notas']
        
        if not notas:
            promedio = None
            estado = 'N/A'
        else:
            promedio = sum(notas) / len(notas)
            
            if promedio >= 61:
                estado = 'Aprobado'
                aprobados += 1
            else:
                estado = 'Reprobado'
                reprobados += 1
        
        prom_str = f'{promedio:.2f}' if promedio is not None else '---'
        print(f'{nombre:<15} | {prom_str:<10} | {estado}')

    print('-' * 40)
    print(f'Total aprobados: {aprobados}')
    print(f'Total reprobados: {reprobados}')

curso = [
    {'nombre': 'Ana López',   'notas': [85, 90, 78, 92]},
    {'nombre': 'Carlos Ruiz',  'notas': [55, 48, 60, 52]},
    {'nombre': 'María Paz',    'notas': [70, 75, 68, 80]},
    {'nombre': 'Luis Gómez',   'notas': [95, 98, 100, 92]},
    {'nombre': 'Sara Díaz',    'notas': [40, 55, 50, 45]},
    {'nombre': 'Pedro Alva',   'notas': []},
]

analizar_curso(curso)
